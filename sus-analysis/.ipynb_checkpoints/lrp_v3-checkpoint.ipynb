# %% [markdown]
# # Usability test of a Web-based AR App

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt
import pingouin as pg

# %%
# Read CSV file with he responses
data = pd.read_csv('lrp_v2.csv', sep=';')

# Make a copy in order to preserve the original.
data_copy = data.copy()
data_copy
# Out:
#     label Sukupuoli          Ikä     Siviilisääty                Koulutus  \
# 0       1    Female      41-50 v       Naimisissa  Ammattilainen tutkinto
# 1       2      Male      31-40 v  Naimaton/Sinkku     Korkeakoulututkinto
# 2       3      Male  Utmost 20 v  Naimaton/Sinkku              Peruskoulu
# 3       4    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 4       5      Male        61+ v       Naimisissa     Korkeakoulututkinto
# 5       6    Female      31-40 v       Naimisissa            Ammattikoulu
# 6       7    Female        61+ v       Naimisissa     Korkeakoulututkinto
# 7       8    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 8       9      Male      41-50 v       Naimisissa            Ammattikoulu
# 9      10      Male      31-40 v       Naimisissa     Kandidaatintutkinto
# 10     11    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 11     12    Female      41-50 v  Naimaton/Sinkku            Ammattikoulu
# 12     13      Male      31-40 v    Parisuhteessa     Korkeakoulututkinto
#
#     SUS1  SUS2  SUS3  SUS4  SUS5  SUS6  SUS7  SUS8  SUS9  SUS10  ARS  \
# 0      5     2     5     2     5     2     5     1     5      2    7
# 1      5     1     5     1     4     1     5     1     4      3    5
# 2      4     4     1     1     4     5     4     4     1      4    4
# 3      2     4     3     1     3     3     5     1     5      1    3
# 4      3     2     4     1     4     2     4     2     4      1    7
# 5      4     2     2     1     5     2     5     1     5      2    5
# 6      2     4     2     4     1     5     4     4     2      3    3
# 7      5     1     5     1     5     1     5     1     5      1    7
# 8      3     3     3     1     5     1     5     1     3      1    4
# 9      1     5     1     1     2     5     3     5     1      1    1
# 10     5     2     3     1     3     1     5     4     5      1    4
# 11     3     4     2     1     2     3     2     2     3      1    4
# 12     4     2     4     1     4     2     4     1     4      2    7
#
#    Oletko käyttänyt jotain AR-sovellusta aiemmin?  \
# 0                                              Ei
# 1                                           Kyllä
# 2                                              Ei
# 3                                              Ei
# 4                                              Ei
# 5                                              Ei
# 6                                              Ei
# 7                                           Kyllä
# 8                                              Ei
# 9                                           Kyllä
# 10                                             Ei
# 11                                             Ei
# 12                                             Ei
#
#    Kuinka tämän AR-sovelluksen käyttö oli verrattavissa muihin käyttämiisi AR -sovelluksiin?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                           Helpompaa
# 8                                                 NaN
# 9   Ohjelma ei toiminut kunnolla. Koodien skannaam...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#    Oletko fyysisesti aktiivinen säännöllisesti? (Liikut, harjoittelet tai urheilet säännöllisesti)  \
# 0                                               Kyllä
# 1                                               Kyllä
# 2                                               Kyllä
# 3                                               Kyllä
# 4                                                  Ei
# 5                                               Kyllä
# 6                                               Kyllä
# 7                                               Kyllä
# 8                                               Kyllä
# 9                                               Kyllä
# 10                                              Kyllä
# 11                                                 Ei
# 12                                              Kyllä
#
#    Kuinka monta tuntia olet fyysisesti aktiivinen viikoittain?: Tuntia
# 0                                                   3
# 1                                                   3
# 2                                                  20
# 3                                                 5-7
# 4                                                  14
# 5                                                   5
# 6                                                 5-6
# 7                                                   8
# 8                                                 6-8
# 9                                                   6
# 10                                                5-7
# 11                                                  4
# 12                                                  8

# %% [markdown]
# ## Calculating SUS Scores
# To calculate the SUS score, first sum the score contributions from each item. Each item's score contribution will range from 0 to 4. For items 1,3,5,7 and 9, the score contribution is the scale position minus 1. For items 2,4,6,8 and 10, the contribution is 5 minus the scale position. Multiply the sum of the scores by 2.5 to obtain the overall value of SUS. SUS scores have a range of 0 to 100, where the higher the value, the higher level of usability.
#
# Brooke, J. (1996). SUS - A quick and dirty usability scale. Usability evaluation in industry, 189(194), 4-7

# %%
# Create a list to store the data
sus = []

# For each row in the column,
for index, row in data_copy.iterrows():
    odd = (row['SUS1'] + row['SUS3'] + row['SUS5'] + row['SUS7'] + row['SUS9']) - 5
    even = 25 - (row['SUS2'] + row['SUS4'] + row['SUS6'] + row['SUS8'] + row['SUS10'])
    sus_scores = (odd + even) * 2.5
    sus.append(sus_scores)
    print(sus_scores)
# Out:
# 90.0
# 90.0
# 40.0
# 70.0
# 77.5
# 82.5
# 27.5
# 100.0
# 80.0
# 27.5
# 80.0
# 52.5
# 80.0

# %%
# Add the SUS scores column to the dataframe
data_copy['SUS Scores'] = sus
data_copy
# Out:
#     label Sukupuoli          Ikä     Siviilisääty                Koulutus  \
# 0       1    Female      41-50 v       Naimisissa  Ammattilainen tutkinto
# 1       2      Male      31-40 v  Naimaton/Sinkku     Korkeakoulututkinto
# 2       3      Male  Utmost 20 v  Naimaton/Sinkku              Peruskoulu
# 3       4    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 4       5      Male        61+ v       Naimisissa     Korkeakoulututkinto
# 5       6    Female      31-40 v       Naimisissa            Ammattikoulu
# 6       7    Female        61+ v       Naimisissa     Korkeakoulututkinto
# 7       8    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 8       9      Male      41-50 v       Naimisissa            Ammattikoulu
# 9      10      Male      31-40 v       Naimisissa     Kandidaatintutkinto
# 10     11    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 11     12    Female      41-50 v  Naimaton/Sinkku            Ammattikoulu
# 12     13      Male      31-40 v    Parisuhteessa     Korkeakoulututkinto
#
#     SUS1  SUS2  SUS3  SUS4  SUS5  ...  SUS7  SUS8  SUS9  SUS10  ARS  \
# 0      5     2     5     2     5  ...     5     1     5      2    7
# 1      5     1     5     1     4  ...     5     1     4      3    5
# 2      4     4     1     1     4  ...     4     4     1      4    4
# 3      2     4     3     1     3  ...     5     1     5      1    3
# 4      3     2     4     1     4  ...     4     2     4      1    7
# 5      4     2     2     1     5  ...     5     1     5      2    5
# 6      2     4     2     4     1  ...     4     4     2      3    3
# 7      5     1     5     1     5  ...     5     1     5      1    7
# 8      3     3     3     1     5  ...     5     1     3      1    4
# 9      1     5     1     1     2  ...     3     5     1      1    1
# 10     5     2     3     1     3  ...     5     4     5      1    4
# 11     3     4     2     1     2  ...     2     2     3      1    4
# 12     4     2     4     1     4  ...     4     1     4      2    7
#
#     Oletko käyttänyt jotain AR-sovellusta aiemmin?  \
# 0                                               Ei
# 1                                            Kyllä
# 2                                               Ei
# 3                                               Ei
# 4                                               Ei
# 5                                               Ei
# 6                                               Ei
# 7                                            Kyllä
# 8                                               Ei
# 9                                            Kyllä
# 10                                              Ei
# 11                                              Ei
# 12                                              Ei
#
#    Kuinka tämän AR-sovelluksen käyttö oli verrattavissa muihin käyttämiisi AR -sovelluksiin?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                           Helpompaa
# 8                                                 NaN
# 9   Ohjelma ei toiminut kunnolla. Koodien skannaam...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#    Oletko fyysisesti aktiivinen säännöllisesti? (Liikut, harjoittelet tai urheilet säännöllisesti)  \
# 0                                               Kyllä
# 1                                               Kyllä
# 2                                               Kyllä
# 3                                               Kyllä
# 4                                                  Ei
# 5                                               Kyllä
# 6                                               Kyllä
# 7                                               Kyllä
# 8                                               Kyllä
# 9                                               Kyllä
# 10                                              Kyllä
# 11                                                 Ei
# 12                                              Kyllä
#
#    Kuinka monta tuntia olet fyysisesti aktiivinen viikoittain?: Tuntia  \
# 0                                                   3
# 1                                                   3
# 2                                                  20
# 3                                                 5-7
# 4                                                  14
# 5                                                   5
# 6                                                 5-6
# 7                                                   8
# 8                                                 6-8
# 9                                                   6
# 10                                                5-7
# 11                                                  4
# 12                                                  8
#
#    SUS Scores
# 0        90.0
# 1        90.0
# 2        40.0
# 3        70.0
# 4        77.5
# 5        82.5
# 6        27.5
# 7       100.0
# 8        80.0
# 9        27.5
# 10       80.0
# 11       52.5
# 12       80.0
#
# [13 rows x 21 columns]

# %%
# Rename the ARS column
data_copy.rename(columns = {'ARS': 'Adjective Rating'}, inplace = True)
data_copy
# Out:
#     label Sukupuoli          Ikä     Siviilisääty                Koulutus  \
# 0       1    Female      41-50 v       Naimisissa  Ammattilainen tutkinto
# 1       2      Male      31-40 v  Naimaton/Sinkku     Korkeakoulututkinto
# 2       3      Male  Utmost 20 v  Naimaton/Sinkku              Peruskoulu
# 3       4    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 4       5      Male        61+ v       Naimisissa     Korkeakoulututkinto
# 5       6    Female      31-40 v       Naimisissa            Ammattikoulu
# 6       7    Female        61+ v       Naimisissa     Korkeakoulututkinto
# 7       8    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 8       9      Male      41-50 v       Naimisissa            Ammattikoulu
# 9      10      Male      31-40 v       Naimisissa     Kandidaatintutkinto
# 10     11    Female      41-50 v       Naimisissa     Korkeakoulututkinto
# 11     12    Female      41-50 v  Naimaton/Sinkku            Ammattikoulu
# 12     13      Male      31-40 v    Parisuhteessa     Korkeakoulututkinto
#
#     SUS1  SUS2  SUS3  SUS4  SUS5  ...  SUS7  SUS8  SUS9  SUS10  \
# 0      5     2     5     2     5  ...     5     1     5      2
# 1      5     1     5     1     4  ...     5     1     4      3
# 2      4     4     1     1     4  ...     4     4     1      4
# 3      2     4     3     1     3  ...     5     1     5      1
# 4      3     2     4     1     4  ...     4     2     4      1
# 5      4     2     2     1     5  ...     5     1     5      2
# 6      2     4     2     4     1  ...     4     4     2      3
# 7      5     1     5     1     5  ...     5     1     5      1
# 8      3     3     3     1     5  ...     5     1     3      1
# 9      1     5     1     1     2  ...     3     5     1      1
# 10     5     2     3     1     3  ...     5     4     5      1
# 11     3     4     2     1     2  ...     2     2     3      1
# 12     4     2     4     1     4  ...     4     1     4      2
#
#     Adjective Rating  Oletko käyttänyt jotain AR-sovellusta aiemmin?  \
# 0                  7                                              Ei
# 1                  5                                           Kyllä
# 2                  4                                              Ei
# 3                  3                                              Ei
# 4                  7                                              Ei
# 5                  5                                              Ei
# 6                  3                                              Ei
# 7                  7                                           Kyllä
# 8                  4                                              Ei
# 9                  1                                           Kyllä
# 10                 4                                              Ei
# 11                 4                                              Ei
# 12                 7                                              Ei
#
#    Kuinka tämän AR-sovelluksen käyttö oli verrattavissa muihin käyttämiisi AR -sovelluksiin?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                           Helpompaa
# 8                                                 NaN
# 9   Ohjelma ei toiminut kunnolla. Koodien skannaam...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#    Oletko fyysisesti aktiivinen säännöllisesti? (Liikut, harjoittelet tai urheilet säännöllisesti)  \
# 0                                               Kyllä
# 1                                               Kyllä
# 2                                               Kyllä
# 3                                               Kyllä
# 4                                                  Ei
# 5                                               Kyllä
# 6                                               Kyllä
# 7                                               Kyllä
# 8                                               Kyllä
# 9                                               Kyllä
# 10                                              Kyllä
# 11                                                 Ei
# 12                                              Kyllä
#
#    Kuinka monta tuntia olet fyysisesti aktiivinen viikoittain?: Tuntia  \
# 0                                                   3
# 1                                                   3
# 2                                                  20
# 3                                                 5-7
# 4                                                  14
# 5                                                   5
# 6                                                 5-6
# 7                                                   8
# 8                                                 6-8
# 9                                                   6
# 10                                                5-7
# 11                                                  4
# 12                                                  8
#
#    SUS Scores
# 0        90.0
# 1        90.0
# 2        40.0
# 3        70.0
# 4        77.5
# 5        82.5
# 6        27.5
# 7       100.0
# 8        80.0
# 9        27.5
# 10       80.0
# 11       52.5
# 12       80.0
#
# [13 rows x 21 columns]

# %%
# Summary statistics for the SUS scores
data_copy['SUS Scores'].describe().round(2)
# Out:
# count     13.00
# mean      69.04
# std       24.19
# min       27.50
# 25%       52.50
# 50%       80.00
# 75%       82.50
# max      100.00
# Name: SUS Scores, dtype: float64

# %%
# Summary statistics for the Adjective Rating Scale 
data_copy['Adjective Rating'].describe().round(2)
# Out:
# count    13.00
# mean      4.69
# std       1.89
# min       1.00
# 25%       4.00
# 50%       4.00
# 75%       7.00
# max       7.00
# Name: Adjective Rating, dtype: float64

# %% [markdown]
# ## Correlation
# Calculating the correlation between SUS Scores and the adjective rating scale - a correlational analysis to reveal how well the SUS scores match with the adjective rating scale as describe in [Bangor, Kortum and Miller (2009)](https://uxpajournal.org/determining-what-individual-sus-scores-mean-adding-an-adjective-rating-scale/).

# %%
# Calculating the correlation between SUS Scores and the Adjective Rating Scale
pg.corr(x=data_copy['SUS Scores'], y=data_copy['Adjective Rating'])
# Out:
#           n         r         CI95%        r2    adj_r2     p-val    BF10  \
# pearson  13  0.754965  [0.35, 0.92]  0.569972  0.483966  0.002851  18.537
#
#             power
# pearson  0.893169

# %% [markdown]
# The results are inline with earlier findings showing a positive correlation between the SUS scores and the adjective rating scale (r = 0.75).

# %%
# Plotting with 95% CI and the regression line extended to the axis limits
sns.set(style="whitegrid")
sns.regplot(x="SUS Scores",
            y="Adjective Rating",
            data=data_copy,
            ci=95,
            truncate=False)
# Out:
# <AxesSubplot:xlabel='SUS Scores', ylabel='Adjective Rating'>
